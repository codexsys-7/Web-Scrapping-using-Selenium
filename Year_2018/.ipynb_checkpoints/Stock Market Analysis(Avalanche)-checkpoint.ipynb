# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('AVN.csv')
df.head()
# Out:
#           Time   Open   High    Low  Close  Volume
# 0  Jan 1, 2018  34.32  35.45  34.30  35.18   63500
# 1  Jan 2, 2018  35.13  35.45  34.95  35.07   97500
# 2  Jan 3, 2018  35.10  35.90  35.01  35.29  179000
# 3  Jan 4, 2018  35.40  35.75  35.12  35.52   87000
# 4  Jan 5, 2018  35.65  37.29  35.65  37.19  733000

# %%
df.shape
# Out:
# (247, 6)

# %%
df[df['Volume'] > 300000]
# Out:
#              Time   Open   High    Low  Close   Volume
# 4     Jan 5, 2018  35.65  37.29  35.65  37.19   733000
# 5     Jan 8, 2018  37.18  39.04  37.15  39.04   361500
# 6     Jan 9, 2018  39.90  40.89  39.04  40.59   446500
# 7    Jan 10, 2018  40.45  41.65  40.45  41.01   302000
# 17   Jan 24, 2018  40.48  41.65  40.05  40.32   549000
# ..            ...    ...    ...    ...    ...      ...
# 225  Nov 29, 2018  86.00  88.65  85.90  87.92   319000
# 226  Nov 30, 2018  88.90  90.51  85.00  87.22   582000
# 239  Dec 19, 2018  79.70  80.50  75.65  77.23  1257000
# 240  Dec 20, 2018  77.50  81.09  76.16  79.06   512500
# 241  Dec 21, 2018  78.10  81.15  76.00  80.41   850500
#
# [92 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Time      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
#ax= plt.figure(figsize =(12,8))

# %%
plt.figure(figsize = (12,7))
df['Time'] = pd.to_datetime(df.Time)
sns.lineplot(df['Time'], df['Close'], legend = 'full')
plt.xticks(rotation = 45)
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.plot(df['Time'], df['Close'])
plt.legend('Close')
plt.show()

# %%
days = 25
df['new_col'] = df['Close'].rolling(days).mean()
df.head()
# Out:
#         Time   Open   High    Low  Close  Volume  new_col
# 0 2018-01-01  34.32  35.45  34.30  35.18   63500      NaN
# 1 2018-01-02  35.13  35.45  34.95  35.07   97500      NaN
# 2 2018-01-03  35.10  35.90  35.01  35.29  179000      NaN
# 3 2018-01-04  35.40  35.75  35.12  35.52   87000      NaN
# 4 2018-01-05  35.65  37.29  35.65  37.19  733000      NaN

# %%
plt.figure(figsize =(12,7))
sns.lineplot(df['Time'], df['new_col'])
sns.lineplot(df['Time'], df['Close'])
plt.legend('Close')
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
days = [10, 20, 30]
for i in days:
    col_name = 'my_avg_'+str(i)+'_days'
    df[col_name] = df['Close'].rolling(i).mean()

# %%
df.head(20)
# Out:
#          Time   Open   High    Low  Close  Volume  new_col  my_avg_10_days  \
# 0  2018-01-01  34.32  35.45  34.30  35.18   63500      NaN             NaN
# 1  2018-01-02  35.13  35.45  34.95  35.07   97500      NaN             NaN
# 2  2018-01-03  35.10  35.90  35.01  35.29  179000      NaN             NaN
# 3  2018-01-04  35.40  35.75  35.12  35.52   87000      NaN             NaN
# 4  2018-01-05  35.65  37.29  35.65  37.19  733000      NaN             NaN
# 5  2018-01-08  37.18  39.04  37.15  39.04  361500      NaN             NaN
# 6  2018-01-09  39.90  40.89  39.04  40.59  446500      NaN             NaN
# 7  2018-01-10  40.45  41.65  40.45  41.01  302000      NaN             NaN
# 8  2018-01-11  41.05  41.45  40.00  40.27  122000      NaN             NaN
# 9  2018-01-12  40.30  40.30  38.26  38.49  170000      NaN          37.765
# 10 2018-01-15  37.25  38.00  36.90  37.08   89500      NaN          37.955
# 11 2018-01-16  37.47  38.50  37.47  37.51   75500      NaN          38.199
# 12 2018-01-17  37.60  38.61  37.50  38.60   84000      NaN          38.530
# 13 2018-01-18  39.20  39.78  38.41  38.68  117000      NaN          38.846
# 14 2018-01-19  38.75  39.25  38.60  38.93  109500      NaN          39.020
# 15 2018-01-22  39.50  39.71  38.65  39.20  120500      NaN          39.036
# 16 2018-01-23  39.10  40.50  38.60  39.79  237500      NaN          38.956
# 17 2018-01-24  40.48  41.65  40.05  40.32  549000      NaN          38.887
# 18 2018-01-25  40.30  40.95  40.00  40.48  177000      NaN          38.908
# 19 2018-01-26  40.15  40.80  39.51  40.57  107500      NaN          39.116
#
#     my_avg_20_days  my_avg_30_days
# 0              NaN             NaN
# 1              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN
# 5              NaN             NaN
# 6              NaN             NaN
# 7              NaN             NaN
# 8              NaN             NaN
# 9              NaN             NaN
# 10             NaN             NaN
# 11             NaN             NaN
# 12             NaN             NaN
# 13             NaN             NaN
# 14             NaN             NaN
# 15             NaN             NaN
# 16             NaN             NaN
# 17             NaN             NaN
# 18             NaN             NaN
# 19         38.4405             NaN

# %%
plt.figure(figsize = (18,12))
sns.lineplot(df['Time'], df['Close'])
sns.lineplot(df['Time'], df['new_col'])
sns.lineplot(df['Time'], df['my_avg_10_days'])
sns.lineplot(df['Time'], df['my_avg_20_days'])
sns.lineplot(df['Time'], df['my_avg_30_days'])
plt.plot()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# []

# %% [markdown]
# # Daily Returns

# %%
df['daily_open'] = df['Open'].pct_change()
df['daily_close'] = df['Close'].pct_change()

# %%
plt.figure(figsize =(12,8))
sns.lineplot(df['Time'], df['daily_open'])
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize =(12,8))
sns.lineplot(df['Time'], df['daily_close'])
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize =(12,8))
sns.distplot(df['daily_open'].dropna(), color ='blue')
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize =(12,8))
sns.distplot(df['daily_close'].dropna(), color ='blue')
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
