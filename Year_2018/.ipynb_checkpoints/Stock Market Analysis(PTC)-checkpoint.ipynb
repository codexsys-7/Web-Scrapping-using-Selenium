# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('PTC.csv')
df.head()
# Out:
#           Time   Open   High    Low  Close    Volume
# 0  Jan 1, 2018  13.02  13.50  12.77  13.34   1047000
# 1  Jan 2, 2018  13.10  13.50  13.00  13.21   4448000
# 2  Jan 3, 2018  13.12  13.45  13.05  13.12   2533500
# 3  Jan 4, 2018  13.11  13.91  13.10  13.74  11353500
# 4  Jan 5, 2018  13.75  13.76  13.31  13.50   4170500

# %%
df.shape
# Out:
# (246, 6)

# %%
df[df['Volume'] > 300000]
# Out:
#              Time   Open   High    Low  Close    Volume
# 0     Jan 1, 2018  13.02  13.50  12.77  13.34   1047000
# 1     Jan 2, 2018  13.10  13.50  13.00  13.21   4448000
# 2     Jan 3, 2018  13.12  13.45  13.05  13.12   2533500
# 3     Jan 4, 2018  13.11  13.91  13.10  13.74  11353500
# 4     Jan 5, 2018  13.75  13.76  13.31  13.50   4170500
# ..            ...    ...    ...    ...    ...       ...
# 239  Dec 20, 2018   9.05   9.87   9.05   9.63  11839500
# 240  Dec 21, 2018   9.60   9.78   9.55   9.76    514500
# 241  Dec 24, 2018   9.76   9.85   9.65   9.70    323000
# 243  Dec 27, 2018   9.75   9.84   9.65   9.73    575000
# 244  Dec 28, 2018   9.70   9.80   9.60   9.64    861500
#
# [164 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Time      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
#ax= plt.figure(figsize =(12,8))

# %%
plt.figure(figsize = (12,7))
df['Time'] = pd.to_datetime(df.Time)
sns.lineplot(df['Time'], df['Close'], legend = 'full')
plt.xticks(rotation = 45)
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.plot(df['Time'], df['Close'])
plt.legend('Close')
plt.show()

# %%
days = 25
df['new_col'] = df['Close'].rolling(days).mean()
df.head()
# Out:
#         Time   Open   High    Low  Close    Volume  new_col
# 0 2018-01-01  13.02  13.50  12.77  13.34   1047000      NaN
# 1 2018-01-02  13.10  13.50  13.00  13.21   4448000      NaN
# 2 2018-01-03  13.12  13.45  13.05  13.12   2533500      NaN
# 3 2018-01-04  13.11  13.91  13.10  13.74  11353500      NaN
# 4 2018-01-05  13.75  13.76  13.31  13.50   4170500      NaN

# %%
plt.figure(figsize =(12,7))
sns.lineplot(df['Time'], df['new_col'])
sns.lineplot(df['Time'], df['Close'])
plt.legend('Close')
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
days = [10, 20, 30]
for i in days:
    col_name = 'my_avg_'+str(i)+'_days'
    df[col_name] = df['Close'].rolling(i).mean()

# %%
df.head(20)
# Out:
#          Time   Open   High    Low  Close    Volume  new_col  my_avg_10_days  \
# 0  2018-01-01  13.02  13.50  12.77  13.34   1047000      NaN             NaN
# 1  2018-01-02  13.10  13.50  13.00  13.21   4448000      NaN             NaN
# 2  2018-01-03  13.12  13.45  13.05  13.12   2533500      NaN             NaN
# 3  2018-01-04  13.11  13.91  13.10  13.74  11353500      NaN             NaN
# 4  2018-01-05  13.75  13.76  13.31  13.50   4170500      NaN             NaN
# 5  2018-01-08  13.78  13.80  13.43  13.49    948500      NaN             NaN
# 6  2018-01-09  13.42  13.42  13.10  13.20    611500      NaN             NaN
# 7  2018-01-10  13.25  13.70  13.24  13.58   2205000      NaN             NaN
# 8  2018-01-11  13.69  13.95  13.55  13.80   7814000      NaN             NaN
# 9  2018-01-12  13.64  13.70  13.31  13.35    449500      NaN          13.433
# 10 2018-01-15  13.29  13.60  13.00  13.05    729000      NaN          13.404
# 11 2018-01-16  13.24  13.44  12.81  13.07    552500      NaN          13.390
# 12 2018-01-17  13.11  13.25  13.05  13.15    198500      NaN          13.393
# 13 2018-01-18  13.30  13.44  13.14  13.21    299000      NaN          13.340
# 14 2018-01-19  13.23  13.29  13.10  13.12    409500      NaN          13.302
# 15 2018-01-22  13.33  13.40  13.16  13.34    472000      NaN          13.287
# 16 2018-01-23  13.38  13.38  13.19  13.32    346500      NaN          13.299
# 17 2018-01-24  13.32  13.59  13.31  13.38    571000      NaN          13.279
# 18 2018-01-25  13.45  13.59  13.32  13.42    206000      NaN          13.241
# 19 2018-01-26  13.42  13.55  13.36  13.43    202000      NaN          13.249
#
#     my_avg_20_days  my_avg_30_days
# 0              NaN             NaN
# 1              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN
# 5              NaN             NaN
# 6              NaN             NaN
# 7              NaN             NaN
# 8              NaN             NaN
# 9              NaN             NaN
# 10             NaN             NaN
# 11             NaN             NaN
# 12             NaN             NaN
# 13             NaN             NaN
# 14             NaN             NaN
# 15             NaN             NaN
# 16             NaN             NaN
# 17             NaN             NaN
# 18             NaN             NaN
# 19          13.341             NaN

# %%
plt.figure(figsize = (18,12))
sns.lineplot(df['Time'], df['Close'])
sns.lineplot(df['Time'], df['new_col'])
sns.lineplot(df['Time'], df['my_avg_10_days'])
sns.lineplot(df['Time'], df['my_avg_20_days'])
sns.lineplot(df['Time'], df['my_avg_30_days'])
plt.plot()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# []

# %% [markdown]
# # Daily Returns

# %%
df['daily_close'] = df['Close'].pct_change()
df['daily_open'] = df['Open'].pct_change()

# %%
plt.figure(figsize = (12,8))
sns.lineplot(df['Time'], df['daily_open'])
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (12,8))
sns.lineplot(df['Time'], df['daily_close'])
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (12,8))
sns.distplot(df['daily_open'].dropna(), color = 'yellow')
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize = (12,8))
sns.distplot(df['daily_close'].dropna(), color = 'yellow')
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
