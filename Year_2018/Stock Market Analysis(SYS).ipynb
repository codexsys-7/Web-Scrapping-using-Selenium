# %%
import warnings
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings( "ignore", module = "matplotlib\..*" )

# %%
df = pd.read_csv('SYS.csv')
df.head()
# Out:
#           Time   Open  High    Low  Close  Volume
# 0  Jan 1, 2018  75.50  75.5  75.00  75.00    4000
# 1  Jan 2, 2018  74.85  76.0  73.11  75.32  197500
# 2  Jan 3, 2018  74.03  74.6  72.30  72.75   21000
# 3  Jan 4, 2018  71.03  74.5  71.03  74.01  381500
# 4  Jan 5, 2018  74.35  77.0  71.00  76.52  180500

# %%
df.shape
# Out:
# (243, 6)

# %%
df[df['Volume'] > 300000]
# Out:
#              Time    Open    High     Low   Close   Volume
# 3     Jan 4, 2018   71.03   74.50   71.03   74.01   381500
# 5     Jan 8, 2018   74.50   80.34   74.50   80.32   436000
# 8    Jan 11, 2018   83.00   83.50   81.00   82.88   734500
# 9    Jan 12, 2018   82.99   84.75   82.00   82.61  1784000
# 17   Jan 24, 2018   83.00   86.11   83.00   84.64   387500
# 19   Jan 26, 2018   83.50   88.35   83.50   87.21   378500
# 33   Feb 16, 2018   86.50   89.00   86.50   88.51   314000
# 37   Feb 22, 2018   88.45   92.13   88.45   92.13   385000
# 52   Mar 15, 2018   90.00   93.60   90.00   93.60  1102000
# 54   Mar 19, 2018   93.02   96.00   93.02   95.42   382500
# 55   Mar 20, 2018   94.05   98.00   94.05   97.00   705000
# 56   Mar 21, 2018   97.00   97.40   94.30   96.29   686500
# 57   Mar 22, 2018   95.95   99.40   95.50   99.05  1136000
# 59   Mar 27, 2018   92.60   95.00   92.60   93.48   406000
# 77   Apr 20, 2018   94.01   94.75   94.00   94.26   788500
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
#ax= plt.figure(figsize =(12,8))

# %%
plt.figure(figsize = (12,7))
df['Time'] = pd.to_datetime(df.Time)
sns.lineplot(df['Time'], df['Close'], legend = 'full')
plt.xticks(rotation = 45)
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.plot(df['Time'], df['Close'])
plt.legend('Close')
ax.show()
# Out:
# <ipython-input-183-9613ee579cfc>:3: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   ax.show()

# %%
days = 25
df['new_col'] = df['Close'].rolling(days).mean()
df.head()
# Out:
#         Time   Open  High    Low  Close  Volume  new_col
# 0 2018-01-01  75.50  75.5  75.00  75.00    4000      NaN
# 1 2018-01-02  74.85  76.0  73.11  75.32  197500      NaN
# 2 2018-01-03  74.03  74.6  72.30  72.75   21000      NaN
# 3 2018-01-04  71.03  74.5  71.03  74.01  381500      NaN
# 4 2018-01-05  74.35  77.0  71.00  76.52  180500      NaN

# %%
plt.figure(figsize =(12,7))
sns.lineplot(df['Time'], df['new_col'])
sns.lineplot(df['Time'], df['Close'])
plt.legend('Close')
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
days = [10, 20, 30]
for i in days:
    col_name = 'my_avg_'+str(i)+'_days'
    df[col_name] = df['Close'].rolling(i).mean()

# %%
df.head(20)
# Out:
#          Time   Open   High    Low  Close   Volume  new_col  my_avg_10_days  \
# 0  2018-01-01  75.50  75.50  75.00  75.00     4000      NaN             NaN
# 1  2018-01-02  74.85  76.00  73.11  75.32   197500      NaN             NaN
# 2  2018-01-03  74.03  74.60  72.30  72.75    21000      NaN             NaN
# 3  2018-01-04  71.03  74.50  71.03  74.01   381500      NaN             NaN
# 4  2018-01-05  74.35  77.00  71.00  76.52   180500      NaN             NaN
# 5  2018-01-08  74.50  80.34  74.50  80.32   436000      NaN             NaN
# 6  2018-01-09  82.40  84.33  81.00  82.98   260500      NaN             NaN
# 7  2018-01-10  84.95  85.00  82.01  83.90    71000      NaN             NaN
# 8  2018-01-11  83.00  83.50  81.00  82.88   734500      NaN             NaN
# 9  2018-01-12  82.99  84.75  82.00  82.61  1784000      NaN          78.629
# 10 2018-01-15  82.10  82.90  81.10  81.99    56500      NaN          79.328
# ...

# %%
plt.figure(figsize = (18,12))
sns.lineplot(df['Time'], df['Close'])
sns.lineplot(df['Time'], df['new_col'])
sns.lineplot(df['Time'], df['my_avg_10_days'])
sns.lineplot(df['Time'], df['my_avg_20_days'])
sns.lineplot(df['Time'], df['my_avg_30_days'])
plt.plot()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# # Daily Returns

# %%
df.head()
# Out:
#         Time   Open  High    Low  Close  Volume  new_col  my_avg_10_days  \
# 0 2018-01-01  75.50  75.5  75.00  75.00    4000      NaN             NaN
# 1 2018-01-02  74.85  76.0  73.11  75.32  197500      NaN             NaN
# 2 2018-01-03  74.03  74.6  72.30  72.75   21000      NaN             NaN
# 3 2018-01-04  71.03  74.5  71.03  74.01  381500      NaN             NaN
# 4 2018-01-05  74.35  77.0  71.00  76.52  180500      NaN             NaN
#
#    my_avg_20_days  my_avg_30_days
# 0             NaN             NaN
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN

# %%
df['daily_open'] = df['Open'].pct_change()

# %%
plt.figure(figsize = (12,8))
sns.lineplot(df['Time'], df['daily_open'])
plt.xticks(rotation = 45)
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['daily_close'] = df['Close'].pct_change()

# %%
plt.figure(figsize = (12,8))
sns.lineplot(df['Time'], df['daily_close'])
plt.xticks(rotation = 45)
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (12,8))
sns.lineplot(df['Time'], df['daily_open'])
sns.lineplot(df['Time'], df['daily_close'])
plt.xticks(rotation = 45)
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (12,8))
sns.distplot(df['daily_close'].dropna(),bins=100, color = 'red')
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize = (12,8))
sns.distplot(df['daily_open'].dropna(),bins=100, color = 'red')
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Correlation

# %%
sys = pd.read_csv('SYS.csv')
ptc = pd.read_csv('PTC.csv')
avn = pd.read_csv('AVN.csv')
nes = pd.read_csv('NETSOL.CSV')

# %%
sys.head()
# Out:
#           Time   Open  High    Low  Close  Volume
# 0  Jan 1, 2018  75.50  75.5  75.00  75.00    4000
# 1  Jan 2, 2018  74.85  76.0  73.11  75.32  197500
# 2  Jan 3, 2018  74.03  74.6  72.30  72.75   21000
# 3  Jan 4, 2018  71.03  74.5  71.03  74.01  381500
# 4  Jan 5, 2018  74.35  77.0  71.00  76.52  180500

# %%
sys['Time'] = pd.to_datetime(df['Time'])
ptc['Time'] = pd.to_datetime(df['Time'])
avn['Time'] = pd.to_datetime(df['Time'])
nes['Time'] = pd.to_datetime(df['Time'])

# %%
avn.head()
# Out:
#         Time   Open   High    Low  Close  Volume
# 0 2018-01-01  34.32  35.45  34.30  35.18   63500
# 1 2018-01-02  35.13  35.45  34.95  35.07   97500
# 2 2018-01-03  35.10  35.90  35.01  35.29  179000
# 3 2018-01-04  35.40  35.75  35.12  35.52   87000
# 4 2018-01-05  35.65  37.29  35.65  37.19  733000

# %%
open_prices = pd.DataFrame({'sys_open':sys['Open'], 'ptc_open':ptc['Open'], 'avn_open':avn['Open'], 'nes_open':nes['Open']})

# %%
open_prices
# Out:
#      sys_open  ptc_open  avn_open  nes_open
# 0       75.50     13.02     34.32     63.29
# 1       74.85     13.10     35.13     65.84
# 2       74.03     13.12     35.10     64.01
# 3       71.03     13.11     35.40     64.00
# 4       74.35     13.75     35.65     64.12
# ..        ...       ...       ...       ...
# 242    105.88      9.69     78.00     79.20
# 243       NaN      9.75     83.75     81.35
# 244       NaN      9.70     84.98     77.00
# 245       NaN      9.60     84.10     71.52
# 246       NaN       NaN     82.50       NaN
#
# [247 rows x 4 columns]

# %%
corrr = open_prices.dropna().corr()
corrr
# Out:
#           sys_open  ptc_open  avn_open  nes_open
# sys_open  1.000000 -0.774059  0.890702  0.796589
# ptc_open -0.774059  1.000000 -0.840259 -0.734917
# avn_open  0.890702 -0.840259  1.000000  0.761624
# nes_open  0.796589 -0.734917  0.761624  1.000000

# %%
plt.figure(figsize = (12,10))
sns.heatmap(corrr,annot = True ,cmap = 'viridis')
plt.show()

# %% [markdown]
# The correlation values are properly separated and easy to comprehend on a heatmap. The highest correlation value is of Systems Ltd and Avanceon, which is 0.9. This means that these two companies are highly correlated in a positive way. So, if the stock value of one company goes up, the value of the other company also goes up and vice versa.

# %%
close_prices = pd.DataFrame({'sys_close':sys['Close'], 'ptc_close':ptc['Close'], 'avn_close':avn['Close'], 'nes_close':nes['Close']})

# %%
close_prices = close_prices.pct_change()
close_prices
# Out:
#      sys_close  ptc_close  avn_close  nes_close
# 0          NaN        NaN        NaN        NaN
# 1     0.004267  -0.009745  -0.003127   0.015533
# 2    -0.034121  -0.006813   0.006273  -0.021107
# 3     0.017320   0.047256   0.006517   0.029688
# 4     0.033914  -0.017467   0.047016   0.024886
# ..         ...        ...        ...        ...
# 242   0.032904   0.006186   0.015297   0.007863
# 243   0.000000  -0.003074   0.036624  -0.048793
# 244   0.000000  -0.009250   0.006853  -0.049993
# 245   0.000000  -0.003112  -0.006220  -0.048513
# 246   0.000000   0.000000  -0.023618   0.000000
#
# [247 rows x 4 columns]

# %%
close_corr = close_prices.dropna().corr()
plt.figure(figsize = (12,10))
sns.heatmap(close_corr, cmap = 'PuBu', annot = True)
plt.show()

# %% [raw]
# The correlation values are properly separated and easy to comprehend on a heatmap. The highest correlation value is of Systems Ltd and Avanceon, which is 0.9. This means that these two companies are highly correlated in a positive way. So, if the stock value of one company goes up, the value of the other company also goes up and vice versa.

# %% [markdown]
# # Return Risk

# %%
df.head()
# Out:
#         Time   Open  High    Low  Close  Volume  new_col  my_avg_10_days  \
# 0 2018-01-01  75.50  75.5  75.00  75.00    4000      NaN             NaN
# 1 2018-01-02  74.85  76.0  73.11  75.32  197500      NaN             NaN
# 2 2018-01-03  74.03  74.6  72.30  72.75   21000      NaN             NaN
# 3 2018-01-04  71.03  74.5  71.03  74.01  381500      NaN             NaN
# 4 2018-01-05  74.35  77.0  71.00  76.52  180500      NaN             NaN
#
#    my_avg_20_days  my_avg_30_days  daily_open  daily_close
# 0             NaN             NaN         NaN          NaN
# 1             NaN             NaN   -0.008609     0.004267
# 2             NaN             NaN   -0.010955    -0.034121
# 3             NaN             NaN   -0.040524     0.017320
# 4             NaN             NaN    0.046741     0.033914

# %%
df['daily_close'].dropna().median()
# Out:
# 0.00023320703620033356

# %%
df['daily_close'].dropna().mean()
# Out:
# 0.0017837249437987277

# %%
close_prices
# Out:
#      sys_close  ptc_close  avn_close  nes_close
# 0          NaN        NaN        NaN        NaN
# 1     0.004267  -0.009745  -0.003127   0.015533
# 2    -0.034121  -0.006813   0.006273  -0.021107
# 3     0.017320   0.047256   0.006517   0.029688
# 4     0.033914  -0.017467   0.047016   0.024886
# ..         ...        ...        ...        ...
# 242   0.032904   0.006186   0.015297   0.007863
# 243   0.000000  -0.003074   0.036624  -0.048793
# 244   0.000000  -0.009250   0.006853  -0.049993
# 245   0.000000  -0.003112  -0.006220  -0.048513
# 246   0.000000   0.000000  -0.023618   0.000000
#
# [247 rows x 4 columns]

# %% [markdown]
# Average Daily Return

# %%
sys_a_d = close_prices['sys_close'].dropna().mean()
sys_a_d
# Out:
# 0.0017547212861759843

# %%
ptc_a_d = close_prices['ptc_close'].dropna().mean()
ptc_a_d
# Out:
# -0.0011730141922160428

# %%
avn_a_d = close_prices['avn_close'].dropna().mean()
avn_a_d
# Out:
# 0.0038429241901132742

# %%
nes_a_d = close_prices['nes_close'].dropna().mean()
nes_a_d
# Out:
# 0.0008965592915066494

# %% [markdown]
# Risk Associated with each Stock

# %%
a = np.std(close_prices['sys_close'])
a
# Out:
# 0.02011670897272671

# %%
b = np.std(close_prices['ptc_close'])
b
# Out:
# 0.017855667659466

# %%
c = np.std(close_prices['avn_close'])
c
# Out:
# 0.02698163222974748

# %%
d = np.std(close_prices['nes_close'])
d
# Out:
# 0.034336875069907395

# %%
avg_daily_return = close_prices.mean()
risk_return = np.std(close_prices)

# %%
print(avg_daily_return)
print(risk_return)
# Out:
# sys_close    0.001755
# ptc_close   -0.001173
# avn_close    0.003843
# nes_close    0.000897
# dtype: float64
# sys_close    0.020117
# ptc_close    0.017856
# avn_close    0.026982
# nes_close    0.034337
# dtype: float64

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(avg_daily_return, risk_return, s = 500)
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
close_prices
# Out:
#      sys_close  ptc_close  avn_close  nes_close
# 0          NaN        NaN        NaN        NaN
# 1     0.004267  -0.009745  -0.003127   0.015533
# 2    -0.034121  -0.006813   0.006273  -0.021107
# 3     0.017320   0.047256   0.006517   0.029688
# 4     0.033914  -0.017467   0.047016   0.024886
# ..         ...        ...        ...        ...
# 242   0.032904   0.006186   0.015297   0.007863
# 243   0.000000  -0.003074   0.036624  -0.048793
# 244   0.000000  -0.009250   0.006853  -0.049993
# 245   0.000000  -0.003112  -0.006220  -0.048513
# 246   0.000000   0.000000  -0.023618   0.000000
#
# [247 rows x 4 columns]

# %%
invest = 100000

# %%
loss_involved = abs(close_prices.quantile(0.1)) * invest
loss_involved
# Out:
# sys_close    2344.682683
# ptc_close    1909.463216
# avn_close    3163.165179
# nes_close    4948.152026
# Name: 0.1, dtype: float64

# %%
abs(close_prices.quantile(0.5)) * invest
# Out:
# sys_close      9.065563
# ptc_close    191.035293
# avn_close    248.164293
# nes_close      5.702555
# Name: 0.5, dtype: float64

# %%
abs(close_prices.quantile(1.0)) * invest
# Out:
# sys_close    5000.000000
# ptc_close    6739.345887
# avn_close    5000.000000
# nes_close    5000.000000
# Name: 1.0, dtype: float64

# %%
sns.scatterplot(loss_involved, invest)
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Predicting Future Stock Prices

# %%
close_prices
# Out:
#      sys_close  ptc_close  avn_close  nes_close
# 0          NaN        NaN        NaN        NaN
# 1     0.004267  -0.009745  -0.003127   0.015533
# 2    -0.034121  -0.006813   0.006273  -0.021107
# 3     0.017320   0.047256   0.006517   0.029688
# 4     0.033914  -0.017467   0.047016   0.024886
# ..         ...        ...        ...        ...
# 242   0.032904   0.006186   0.015297   0.007863
# 243   0.000000  -0.003074   0.036624  -0.048793
# 244   0.000000  -0.009250   0.006853  -0.049993
# 245   0.000000  -0.003112  -0.006220  -0.048513
# 246   0.000000   0.000000  -0.023618   0.000000
#
# [247 rows x 4 columns]

# %% [markdown]
# Random Walk Theory:
# Many analysts believe that the stock market prices follow the random walk theory. This theory states the following:
# The stock market may take random, irregular, and unpredictable paths in determining the prices of stocks.
# It also assumes that past trends are useless in predicting future prices and that the future price only depends on the current price of the stock.

# %% [markdown]
# MonteCarlo simulations
#
# This method uses randomness to solve problems. It converts the randomness in the variables into probability distributions. It then generates a range of future price values in a normal distribution instead of just one value. More detailed information about this can be found here.
#
# The following is the formula for MonteCarlo simulations:
#
# S_{t+1}=S_{t}*e^{Drift+Rv}
#
# Drift=AveragedDailyReturn−DailyReturnVariance/2
#
# Rv=STD * NORMSINV(RAND())
#
# Here, S_{t+1} is the future price of a stock.
#
# S_{t} is the current price of a stock.
# e is the universal constant.
# Drift and Rv are represented by their formulas.
# The Drift component represents the direction of stock, whether it’ll go up or down. The Rv is our random variable; which either pushes the stock price up or down. More information on the NORMSINV() function can be found here.

# %%
log_returns = np.log(1+close_prices['sys_close'])
#log returns
avg_return = np.mean(log_returns)
var_return = log_returns.var()

# Calculating Drift
drift = avg_return - (var_return)/2
drift = np.array(drift)
drift
# Out:
# array(0.00135038)

# %%
#Calculating RV
from scipy.stats import norm
std_return = np.std(log_returns)
std_return = np.array(std_return)
pred_price_overdays = 30
pred_range = 5

x = np.random.rand(pred_price_overdays, pred_range)
rv = std_return * norm.ppf(x)
print('The Required RV array is:', rv)
# Out:
# The Required RV array is: [[-0.01090234  0.00169103  0.00052755 -0.01752047 -0.00621192]
#  [-0.0006493   0.00156203  0.01476219  0.01593116  0.0009745 ]
#  [-0.0126931   0.01976941  0.01535667  0.00557714 -0.0143479 ]
#  [ 0.03209487  0.03066562  0.01221391  0.02792103 -0.0006103 ]
#  [ 0.0098896   0.0042504   0.02966934  0.0099526  -0.01579557]
#  [ 0.03061186  0.03109091  0.0322363  -0.00583602  0.0347614 ]
#  [-0.02765379 -0.01986854 -0.01607165  0.032458    0.02011332]
#  [ 0.00816732 -0.01991899 -0.01305029  0.00688178  0.00484286]
#  [-0.00527371 -0.00112082 -0.00614774  0.02257572 -0.01049109]
#  [-0.01213031  0.0177378   0.0321929   0.0164231   0.00631099]
#  [-0.01299912  0.0116138   0.01142621  0.00109008  0.00828914]
#  [ 0.01422987  0.01949947 -0.00681733 -0.01782868 -0.00178374]
#  [ 0.00055424  0.0088587   0.01861777 -0.02322635  0.02104412]
#  [-0.01357588  0.00978073 -0.01587831 -0.0004705   0.0264264 ]
# ...

# %%
# Calculating e_value
e = np.exp(drift + rv)
print(e)
current_price = df['Close'].iloc[-1]
print(current_price)
new_prices = current_price * e
print(new_prices)
# Out:
# [[0.99049352 1.00304604 1.00187969 0.98395995 0.99515025]
#  [1.00070132 1.00291665 1.01624308 1.01743173 1.00232758]
#  [0.98872137 1.02134439 1.01684739 1.00695157 0.98708658]
#  [1.03401083 1.03253403 1.0136567  1.02970403 1.00074036]
#  [1.01130338 1.0056165  1.03150584 1.0113671  0.98565864]
#  [1.03247851 1.03297325 1.03415708 0.9955244  1.03677173]
#  [0.97403952 0.98165225 0.98538655 1.03438638 1.0216957 ]
#  [1.00956314 0.98160272 0.98836827 1.00826613 1.00621245]
#  [0.99608436 1.00022958 0.99521413 1.02421463 0.99090094]
#  [0.98927797 1.01927153 1.0341122  1.01793237 1.00769079]
#  [0.98841885 1.01304858 1.01285856 1.00244345 1.00968613]
#  [1.01570225 1.02106872 0.99454796 0.98365672 0.99956673]
#  [1.00190644 1.01026137 1.02016884 0.97836157 1.02264714]
#  [0.98784893 1.01119329 0.98557709 1.00088027 1.02816615]
#  [0.96852211 1.01363373 0.99075626 0.9969408  0.99707794]
#  [0.98231189 1.01002705 0.99317137 0.96010086 0.98905222]
# ...

# %%
for i in range(1, pred_price_overdays):
    new_prices[i] = new_prices[i-1] * e[i]

print('The maximum predicted price:', new_prices[pred_price_overdays-1].max())
print('The maximum predicted price:', new_prices[pred_price_overdays-1].min())

print('The PRedicted Prices are:', new_prices)
# Out:
# The maximum predicted price: 134.45235953995316
# The maximum predicted price: 101.86296956060677
# The PRedicted Prices are: [[108.825523   110.20466888 110.07652173 108.10767935 109.33715851]
#  [108.90184505 110.52609735 111.86450318 109.99218326 109.59164964]
#  [107.67358138 112.88520973 113.7491281  110.75680196 108.17644713]
#  [111.33564896 116.55782051 115.30256625 114.04672553 108.25653631]
#  [112.5941186  117.21246703 118.9352706  115.34310659 106.70399   ]
#  [116.25100832 121.07734285 122.99775224 114.8268772  110.62768049]
#  [113.23307577 118.85584603 121.2003313  118.77535733 113.02782559]
#  [114.31593933 116.66922178 119.79056175 119.75717017 113.73000563]
#  [113.86831916 116.69600702 119.21725929 122.65704577 112.69516894]
#  [112.64741939 118.94491723 123.28402237 124.85657751 113.56188382]
#  [111.34283229 120.49697919 124.86927684 125.16165772 114.66185866]
#  [113.0911654  123.03569671 124.18848476 123.11610621 114.61217935]
# ...

# %%
plt.figure(figsize = (15,8))
plt.plot(new_prices)
plt.xlabel('Days')
plt.ylabel('Prices')
plt.title('Monte Carlo Simulation of Predicting Future Prices')
plt.show()
