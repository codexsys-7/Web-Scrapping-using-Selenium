# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('NETSOl.csv')
df.head()
# Out:
#           Time   Open   High   Low  Close  Volume
# 0  Jan 1, 2018  63.29  65.00  63.0  64.38   63000
# 1  Jan 2, 2018  65.84  65.85  63.5  65.38   16000
# 2  Jan 3, 2018  64.01  65.40  63.5  64.00   43000
# 3  Jan 4, 2018  64.00  65.90  64.0  65.90    8000
# 4  Jan 5, 2018  64.12  68.48  64.0  67.54  158000

# %%
df.shape
# Out:
# (246, 6)

# %%
df[df['Volume'] > 300000]
# Out:
#              Time   Open   High    Low  Close   Volume
# 23    Feb 1, 2018  64.80  64.80  61.32  61.33   418000
# 24    Feb 2, 2018  61.90  63.17  60.00  60.16   344500
# 28    Feb 9, 2018  64.60  67.83  63.55  67.50   685000
# 30   Feb 13, 2018  68.00  68.00  67.02  68.00   509000
# 31   Feb 14, 2018  71.40  71.40  69.49  70.76  1313500
# ..            ...    ...    ...    ...    ...      ...
# 241  Dec 24, 2018  80.00  81.50  76.61  80.12  1152300
# 242  Dec 26, 2018  79.20  82.70  79.20  80.75  1003600
# 243  Dec 27, 2018  81.35  82.50  76.72  76.81  2108600
# 244  Dec 28, 2018  77.00  77.29  72.97  72.97  1230600
# 245  Dec 31, 2018  71.52  71.52  69.33  69.43  3639700
#
# [161 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Time      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
#ax= plt.figure(figsize =(12,8))

# %%
plt.figure(figsize = (12,7))
df['Time'] = pd.to_datetime(df.Time)
sns.lineplot(df['Time'], df['Close'], legend = 'full')
plt.xticks(rotation = 45)
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.plot(df['Time'], df['Close'])
plt.legend('Close')
plt.show()

# %%
days = 25
df['new_col'] = df['Close'].rolling(days).mean()
df.head()
# Out:
#         Time   Open   High   Low  Close  Volume  new_col
# 0 2018-01-01  63.29  65.00  63.0  64.38   63000      NaN
# 1 2018-01-02  65.84  65.85  63.5  65.38   16000      NaN
# 2 2018-01-03  64.01  65.40  63.5  64.00   43000      NaN
# 3 2018-01-04  64.00  65.90  64.0  65.90    8000      NaN
# 4 2018-01-05  64.12  68.48  64.0  67.54  158000      NaN

# %%
plt.figure(figsize =(12,7))
sns.lineplot(df['Time'], df['new_col'])
sns.lineplot(df['Time'], df['Close'])
plt.legend('Close')
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
days = [10, 20, 30]
for i in days:
    col_name = 'my_avg_'+str(i)+'_days'
    df[col_name] = df['Close'].rolling(i).mean()

# %%
df.head(20)
# Out:
#          Time   Open   High    Low  Close  Volume  new_col  my_avg_10_days  \
# 0  2018-01-01  63.29  65.00  63.00  64.38   63000      NaN             NaN
# 1  2018-01-02  65.84  65.85  63.50  65.38   16000      NaN             NaN
# 2  2018-01-03  64.01  65.40  63.50  64.00   43000      NaN             NaN
# 3  2018-01-04  64.00  65.90  64.00  65.90    8000      NaN             NaN
# 4  2018-01-05  64.12  68.48  64.00  67.54  158000      NaN             NaN
# 5  2018-01-08  67.60  68.98  66.29  67.81  141000      NaN             NaN
# 6  2018-01-09  68.00  69.20  67.55  67.84   76000      NaN             NaN
# 7  2018-01-10  68.00  69.40  68.00  69.10  161500      NaN             NaN
# 8  2018-01-11  70.00  70.00  67.00  67.27   59000      NaN             NaN
# 9  2018-01-12  67.00  67.00  65.00  66.54   36000      NaN          66.576
# 10 2018-01-15  65.98  66.80  64.50  65.46   25500      NaN          66.684
# ...

# %%
plt.figure(figsize = (18,12))
sns.lineplot(df['Time'], df['Close'])
sns.lineplot(df['Time'], df['new_col'])
sns.lineplot(df['Time'], df['my_avg_10_days'])
sns.lineplot(df['Time'], df['my_avg_20_days'])
sns.lineplot(df['Time'], df['my_avg_30_days'])
plt.plot()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# # Daily Returns

# %%
df['daily_open'] = df['Open'].pct_change()
df['daily_close'] = df['Close'].pct_change()

# %%
plt.figure(figsize =(12,8))
sns.lineplot(df['Time'], df['daily_open'])
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize =(12,8))
sns.lineplot(df['Time'], df['daily_close'])
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize =(12,8))
sns.distplot(df['daily_open'].dropna(), color ='blue')
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize =(12,8))
sns.distplot(df['daily_close'].dropna(), color ='blue')
plt.show()
# Out:
# c:\users\ab\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
